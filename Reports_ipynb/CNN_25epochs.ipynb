# %%
#import libraries
import time
import librosa
import numpy as np
import matplotlib.pyplot as plt
import pdb
import h5py
import my_callbacks
from keras.callbacks import ModelCheckpoint
from keras import backend as K
from CNN_tensor import MusicTaggerCNN
from sklearn.metrics import roc_curve,auc,roc_auc_score
from keras.models import model_from_json
# Out:
# Using TensorFlow backend.

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# %%
#load the dataset
dataset = h5py.File('train.h5', 'r')
train_x = dataset.get('melgram')
train_y = dataset.get('y')
dataset = h5py.File('valid.h5', 'r')
valid_x = dataset.get('melgram')
valid_y = dataset.get('y')
dataset = h5py.File('test.h5', 'r')
test_x = dataset.get('melgram')
test_y = dataset.get('y')

# %%
def main(net):

    print('Running main() with network: %s and backend: %s' % (net, K._BACKEND))

    #load model
    if net == 'cnn':
        model = MusicTaggerCNN(weights=None)

    #print input shape
    print("Expected input shape: ",model.input_shape)
    print("Actual input shape: ",train_x.shape)
    
    #print model info
    model.summary()

    #compile model
    print("Compiling")
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    #prepare callbacks
    histories = my_callbacks.Histories()
    checkpoint= ModelCheckpoint(filepath="weights.hdf5",monitor='val_acc', verbose=0,save_best_only=True, mode='max')
    callbacks_list=[histories,checkpoint]
    
    #train model
    print("Training")
    nb_epoch = 25
    model.fit(train_x, train_y, batch_size=32, nb_epoch=25, verbose=1,callbacks=callbacks_list,validation_data=(test_x,test_y),shuffle="batch")
    
    #print AUC scores
    print("\nAUCs:")
    for index,auc_score in enumerate(histories.aucs):
        print(index,":",auc_score)

        
    #print final AUC, accuracy 
    print("\ntesting on ",valid_x.shape[0]," samples")
    scores = model.evaluate(valid_x, valid_y)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    y_score = model.predict(valid_x)
    fpr, tpr, _ = roc_curve(valid_y[:,0],y_score[:, 0])
    roc_auc = auc(fpr, tpr)
    print("AUC: %f" % roc_auc)
    
    #plot ROC
    plt.figure()
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.plot(fpr,tpr,label='AUC = %0.2f' % roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0, 1], [0,1], 'k--')
    plt.xlim([0.0, 1.05])
    plt.ylim([0.0, 1.05])
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.show()
       
    #auc vs epochs
    epoch_y = list(range(1,nb_epoch+1))
    plt.title('AUC scores vs epoch')
    plt.xticks(np.arange(1,nb_epoch+1,2))
    plt.plot(epoch_y,histories.aucs)
    plt.xlim([1, nb_epoch+1])
    plt.xlabel('Number of epochs')
    plt.ylabel('AUC')
    plt.show()
    
    #loss vs epochs
    epoch_y = list(range(1,nb_epoch+1))
    plt.title('Model Loss')
    plt.xticks(np.arange(1,nb_epoch+1,2))
    plt.plot(epoch_y,histories.loss, color='blue')
    plt.plot(epoch_y,histories.valloss, color='green')
    plt.xlim([1, nb_epoch+1])
    plt.xlabel('Number of epochs')
    plt.ylabel('Loss')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.show()
    
    #save model
    model_json = model.to_json()
    with open("model.json","w") as json_file:
        json_file.write(model_json)
    model.save_weights('model.h5')
    print("Saved model to disk")

# %%
#main function
if __name__ == '__main__':

    networks = ['cnn']
    for net in networks:
    	main(net)
# Out:
# Running main() with network: cnn and backend: tensorflow
# Expected input shape:  (None, 96, 1366)
# Actual input shape:  (18102, 96, 1366)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 96, 1366)      0
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 96, 1366, 1)   0           input_1[0][0]
# ____________________________________________________________________________________________________
# bn_0_freq (BatchNormalization)   (None, 96, 1366, 1)   5464        reshape_1[0][0]
# ____________________________________________________________________________________________________
# conv1 (Convolution2D)            (None, 96, 1366, 32)  320         bn_0_freq[0][0]
# ____________________________________________________________________________________________________
# bn1 (BatchNormalization)         (None, 96, 1366, 32)  128         conv1[0][0]
# ____________________________________________________________________________________________________
# elu_1 (ELU)                      (None, 96, 1366, 32)  0           bn1[0][0]
# ____________________________________________________________________________________________________
# pool1 (MaxPooling2D)             (None, 48, 341, 32)   0           elu_1[0][0]
# ____________________________________________________________________________________________________
# conv2 (Convolution2D)            (None, 48, 341, 128)  36992       pool1[0][0]
# ____________________________________________________________________________________________________
# bn2 (BatchNormalization)         (None, 48, 341, 128)  512         conv2[0][0]
# ____________________________________________________________________________________________________
# elu_2 (ELU)                      (None, 48, 341, 128)  0           bn2[0][0]
# ____________________________________________________________________________________________________
# pool2 (MaxPooling2D)             (None, 24, 85, 128)   0           elu_2[0][0]
# ____________________________________________________________________________________________________
# conv3 (Convolution2D)            (None, 24, 85, 128)   147584      pool2[0][0]
# ____________________________________________________________________________________________________
# bn3 (BatchNormalization)         (None, 24, 85, 128)   512         conv3[0][0]
# ____________________________________________________________________________________________________
# elu_3 (ELU)                      (None, 24, 85, 128)   0           bn3[0][0]
# ____________________________________________________________________________________________________
# pool3 (MaxPooling2D)             (None, 12, 21, 128)   0           elu_3[0][0]
# ____________________________________________________________________________________________________
# conv4 (Convolution2D)            (None, 12, 21, 192)   221376      pool3[0][0]
# ____________________________________________________________________________________________________
# bn4 (BatchNormalization)         (None, 12, 21, 192)   768         conv4[0][0]
# ____________________________________________________________________________________________________
# elu_4 (ELU)                      (None, 12, 21, 192)   0           bn4[0][0]
# ____________________________________________________________________________________________________
# pool4 (MaxPooling2D)             (None, 4, 4, 192)     0           elu_4[0][0]
# ____________________________________________________________________________________________________
# conv5 (Convolution2D)            (None, 4, 4, 256)     442624      pool4[0][0]
# ____________________________________________________________________________________________________
# bn5 (BatchNormalization)         (None, 4, 4, 256)     1024        conv5[0][0]
# ____________________________________________________________________________________________________
# elu_5 (ELU)                      (None, 4, 4, 256)     0           bn5[0][0]
# ____________________________________________________________________________________________________
# pool5 (MaxPooling2D)             (None, 1, 1, 256)     0           elu_5[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 256)           0           pool5[0][0]
# ____________________________________________________________________________________________________
# output (Dense)                   (None, 40)            10280       flatten_1[0][0]
# ====================================================================================================
# Total params: 867,584
# Trainable params: 863,380
# Non-trainable params: 4,204
# ____________________________________________________________________________________________________
# Compiling
# Training
# Train on 18102 samples, validate on 3879 samples
# AUC: 0.5
# Epoch 1/25
# 18102/18102 [==============================] - 282s - loss: 0.1777 - acc: 0.9367 - val_loss: 0.1861 - val_acc: 0.9301
# AUC: 0.874168539515
# Epoch 2/25
# 18102/18102 [==============================] - 283s - loss: 0.1566 - acc: 0.9415 - val_loss: 0.1783 - val_acc: 0.9357
# AUC: 0.889622712744
# Epoch 3/25
# 18102/18102 [==============================] - 284s - loss: 0.1491 - acc: 0.9432 - val_loss: 0.1904 - val_acc: 0.9305
# AUC: 0.891388142836
# Epoch 4/25
# 18102/18102 [==============================] - 289s - loss: 0.1444 - acc: 0.9443 - val_loss: 0.1551 - val_acc: 0.9398
# AUC: 0.902613384328
# Epoch 5/25
# 18102/18102 [==============================] - 285s - loss: 0.1404 - acc: 0.9456 - val_loss: 0.1674 - val_acc: 0.9383
# AUC: 0.89431117194
# Epoch 6/25
# 18102/18102 [==============================] - 282s - loss: 0.1356 - acc: 0.9470 - val_loss: 0.1730 - val_acc: 0.9380
# AUC: 0.894303317482
# Epoch 7/25
# 18102/18102 [==============================] - 282s - loss: 0.1310 - acc: 0.9485 - val_loss: 0.1715 - val_acc: 0.9393
# AUC: 0.901949251366
# Epoch 8/25
# 18102/18102 [==============================] - 285s - loss: 0.1253 - acc: 0.9502 - val_loss: 0.1564 - val_acc: 0.9427
# AUC: 0.905820717166
# Epoch 9/25
# 18102/18102 [==============================] - 284s - loss: 0.1183 - acc: 0.9528 - val_loss: 0.1614 - val_acc: 0.9417
# AUC: 0.904242668047
# Epoch 10/25
# 18102/18102 [==============================] - 282s - loss: 0.1091 - acc: 0.9566 - val_loss: 0.1655 - val_acc: 0.9392
# AUC: 0.902319249941
# Epoch 11/25
# 18102/18102 [==============================] - 282s - loss: 0.0984 - acc: 0.9610 - val_loss: 0.1736 - val_acc: 0.9343
# AUC: 0.901066479756
# Epoch 12/25
# 18102/18102 [==============================] - 288s - loss: 0.0855 - acc: 0.9662 - val_loss: 0.1927 - val_acc: 0.9302
# AUC: 0.897581545309
# Epoch 13/25
# 18102/18102 [==============================] - 284s - loss: 0.0717 - acc: 0.9721 - val_loss: 0.2091 - val_acc: 0.9341
# AUC: 0.888935494619
# Epoch 14/25
# 18102/18102 [==============================] - 281s - loss: 0.0579 - acc: 0.9783 - val_loss: 0.2006 - val_acc: 0.9356
# AUC: 0.889217833504
# Epoch 15/25
# 18102/18102 [==============================] - 282s - loss: 0.0455 - acc: 0.9838 - val_loss: 0.2140 - val_acc: 0.9362
# AUC: 0.883757253297
# Epoch 16/25
# 18102/18102 [==============================] - 279s - loss: 0.0355 - acc: 0.9881 - val_loss: 0.2277 - val_acc: 0.9353
# AUC: 0.883364936822
# Epoch 17/25
# 18102/18102 [==============================] - 280s - loss: 0.0271 - acc: 0.9917 - val_loss: 0.2438 - val_acc: 0.9290
# AUC: 0.875787373983
# Epoch 18/25
# 18102/18102 [==============================] - 278s - loss: 0.0213 - acc: 0.9940 - val_loss: 0.2645 - val_acc: 0.9361
# AUC: 0.876364560492
# Epoch 19/25
# 18102/18102 [==============================] - 287s - loss: 0.0170 - acc: 0.9955 - val_loss: 0.2718 - val_acc: 0.9301
# AUC: 0.873824064663
# Epoch 20/25
# 18102/18102 [==============================] - 282s - loss: 0.0144 - acc: 0.9964 - val_loss: 0.2924 - val_acc: 0.9314
# AUC: 0.875019951475
# Epoch 21/25
# 18102/18102 [==============================] - 279s - loss: 0.0120 - acc: 0.9971 - val_loss: 0.3039 - val_acc: 0.9332
# AUC: 0.877565155581
# Epoch 22/25
# 18102/18102 [==============================] - 280s - loss: 0.0106 - acc: 0.9974 - val_loss: 0.3165 - val_acc: 0.9356
# AUC: 0.871419172863
# Epoch 23/25
# 18102/18102 [==============================] - 280s - loss: 0.0114 - acc: 0.9970 - val_loss: 0.3203 - val_acc: 0.9326
# AUC: 0.867785340267
# Epoch 24/25
# 18102/18102 [==============================] - 283s - loss: 0.0108 - acc: 0.9970 - val_loss: 0.3232 - val_acc: 0.9309
# AUC: 0.874991276614
# Epoch 25/25
# 18102/18102 [==============================] - 283s - loss: 0.0088 - acc: 0.9977 - val_loss: 0.3329 - val_acc: 0.9346
#
# AUCs:
# 0 : 0.874168539515
# 1 : 0.889622712744
# 2 : 0.891388142836
# 3 : 0.902613384328
# 4 : 0.89431117194
# 5 : 0.894303317482
# 6 : 0.901949251366
# 7 : 0.905820717166
# 8 : 0.904242668047
# 9 : 0.902319249941
# 10 : 0.901066479756
# 11 : 0.897581545309
# 12 : 0.888935494619
# 13 : 0.889217833504
# 14 : 0.883757253297
# 15 : 0.883364936822
# 16 : 0.875787373983
# 17 : 0.876364560492
# 18 : 0.873824064663
# 19 : 0.875019951475
# 20 : 0.877565155581
# 21 : 0.871419172863
# 22 : 0.867785340267
# 23 : 0.874991276614
# 24 : 0.872164643208
#
# testing on  3879  samples
# 3879/3879 [==============================] - 25s
# acc: 93.30%
# AUC: 0.830162
# Saved model to disk
